# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter
import seaborn as sns
sns.set_context('talk')

# Plot Style
plt.style.use(u'ggplot')

# Read in training Data File
df = pd.read_json("C:/Users/chloe/Desktop/3B/MSCI436Project/train.json")

#Most Common Ingredients

ingr_ind = Counter([ingredient for ingredient_list in train.ingredients for ingredient in ingredient_list])
ingr_ind = pd.DataFrame.from_dict(ingr_ind,orient='index').reset_index()
ingr_ind = ingr_ind.rename(columns={'index':'Ingredient', 0:'Count'})


# Plot Cuisine Distribution
f, ax = plt.subplots(figsize=(15,13))
sns.countplot(y = 'cuisine', 
                   data = df,
                  order = df.cuisine.value_counts(ascending=False).index,
             palette = "RdBu")

# Plot Ingredient Distribution
f, ax = plt.subplots(figsize=(13,10))
sns.barplot(x = 'Count', 
            y = 'Ingredient',
            data = ingr_ind.sort_values('Count', ascending=False).head(20),
           palette="RdBu")

# %%
#Least Common Ingredients

ingr_ind = Counter([ingredient for ingredient_list in train.ingredients for ingredient in ingredient_list])
ingr_ind = pd.DataFrame.from_dict(ingr_ind,orient='index').reset_index()
ingr_ind = ingr_ind.rename(columns={'index':'Ingredient', 0:'Count'})
ingr_ind.sort_values('Count', ascending=True).head(20)
# Out:
#                    Ingredient  Count
# 6713  crushed cheese crackers      1
# 5194              mora chiles      1
# 5195      double smoked bacon      1
# 5198        Mazola Canola Oil      1
# 5201        seasoned croutons      1
# 1757          turkey hot dogs      1
# 5202         avocado dressing      1
# 5203       light kidney beans      1
# 5205       white bread slices      1
# 1747                fiber one      1
# 5210   honey mustard dressing      1
# 5211  whole wheat bread cubes      1
# 5215    vanilla frozen yogurt      1
# 5220             waffle fries      1
# 5222     unsweetened iced tea      1
# 5223        jamaican jerk rub      1
# 5224               beef cheek      1
# 5227              lemon vodka      1
# 5230            Fisher Pecans      1
# 1711              bread yeast      1

# %%
#Plot Ingredient Count
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_context('talk')

f, ax = plt.subplots(figsize=(32,15))
sns.boxplot(x='cuisine',
            y='number_ingredients',
            data= (pd.concat([train.cuisine,train.ingredients.map(lambda l: len(l))], axis=1)
                    .rename(columns={'ingredients':'number_ingredients'})),
            palette="Blues"
            )

# %%
import pandas as pd
import numpy as np

df = pd.read_json("C:/Users/chloe/Desktop/3B/MSCI436Project/train.json", orient='records')

#print number of records
print("Number of records: {0}".format(len(df.id)))
print("---")
# printing cuisine types and counts
print("Percent of data from each cusine:")

print(df.cuisine.value_counts(normalize=True))
print("---")
print("Number of cuisine types: {0}".format(len(df.cuisine.value_counts())))
print("---")
print("Number of unique ingredients: {0}".format(len(set([ingredient for ingredient_list in df.ingredients.values for ingredient in ingredient_list]))))
# Out:
# Number of records: 39774
# ---
# Percent of data from each cusine:
# italian         0.197063
# mexican         0.161865
# southern_us     0.108614
# indian          0.075502
# chinese         0.067205
# french          0.066526
# cajun_creole    0.038870
# thai            0.038694
# japanese        0.035777
# greek           0.029542
# spanish         0.024865
# korean          0.020868
# vietnamese      0.020742
# moroccan        0.020642
# british         0.020214
# filipino        0.018982
# irish           0.016770
# jamaican        0.013225
# russian         0.012294
# brazilian       0.011741
# Name: cuisine, dtype: float64
# ---
# Number of cuisine types: 20
# ---
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-76-cbc4cef9b134> in <module>
#      14 print("Number of cuisine types: {0}".format(len(df.cuisine.value_counts())))
#      15 print("---")
# ---> 16 print("Number of unique ingredients: {0}".format(len(set([ingredient for ingredient_list in df.ingredients.values]))))
#
# <ipython-input-76-cbc4cef9b134> in <listcomp>(.0)
#      14 print("Number of cuisine types: {0}".format(len(df.cuisine.value_counts())))
#      15 print("---")
# ---> 16 print("Number of unique ingredients: {0}".format(len(set([ingredient for ingredient_list in df.ingredients.values]))))
#
# NameError: name 'ingredient' is not defined
