# %%
# Import libraries
import pandas as pd
import numpy as np
import networkx as nx  
import json
import random
import collections
import matplotlib.pyplot as plt
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

# %%
# read in JSON into dataframe
def preprocess():
    with open('./data/train.json') as json_file:
        df = pd.read_json(json_file, orient='columns')
        cuisines = df.cuisine.unique()
    return df, cuisines

# %%
# encode data for apriori algo
encoder = TransactionEncoder()
arr = encoder.fit(dataset).transform(dataset)
df = pd.DataFrame(arr, columns=encoder.columns_)

# %%
# define frequent itemsets
frequent_itemsets = apriori(df, min_support=0.05, use_colnames=True)
frequent_itemsets
# Out:
#      support                     itemsets
# 0   0.116458          (all-purpose flour)
# 1   0.066048               (black pepper)
# 2   0.121864                     (butter)
# 3   0.070750                    (carrots)
# 4   0.051189               (chili powder)
# 5   0.085181                       (eggs)
# 6   0.069065     (extra-virgin olive oil)
# 7   0.185548                     (garlic)
# 8   0.156786              (garlic cloves)
# 9   0.077387               (green onions)
# 10  0.120280        (ground black pepper)
# 11  0.069065               (ground cumin)
# 12  0.078267                (kosher salt)
# 13  0.074119                 (large eggs)
# 14  0.056896                       (milk)
# 15  0.200407                  (olive oil)
# 16  0.200432                     (onions)
# 17  0.111580                     (pepper)
# 18  0.453764                       (salt)
# 19  0.082868                  (soy sauce)
# 20  0.161764                      (sugar)
# 21  0.076884                   (tomatoes)
# 22  0.069945            (unsalted butter)
# 23  0.110248              (vegetable oil)
# 24  0.187484                      (water)
# 25  0.077412    (all-purpose flour, salt)
# 26  0.069819               (butter, salt)
# 27  0.052295          (olive oil, garlic)
# 28  0.066853             (garlic, onions)
# 29  0.094258               (garlic, salt)
# 30  0.052798   (olive oil, garlic cloves)
# 31  0.075300        (garlic cloves, salt)
# 32  0.068738  (salt, ground black pepper)
# 33  0.055489          (olive oil, onions)
# 34  0.105018            (olive oil, salt)
# 35  0.110424               (onions, salt)
# 36  0.096646               (salt, pepper)
# 37  0.076960                (salt, sugar)
# 38  0.052823        (salt, vegetable oil)
# 39  0.099563                (salt, water)

# %%
# create association rules
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.2)
print(rules[['antecedents', 'consequents', 'support', 'confidence']])
# Out:
#               antecedents      consequents   support  confidence
# 0     (all-purpose flour)           (salt)  0.077412    0.664724
# 1                (butter)           (salt)  0.069819    0.572932
# 2             (olive oil)         (garlic)  0.052295    0.260946
# 3                (garlic)      (olive oil)  0.052295    0.281843
# 4                (garlic)         (onions)  0.066853    0.360298
# 5                (onions)         (garlic)  0.066853    0.333542
# 6                (garlic)           (salt)  0.094258    0.507995
# 7                  (salt)         (garlic)  0.094258    0.207724
# 8             (olive oil)  (garlic cloves)  0.052798    0.263455
# 9         (garlic cloves)      (olive oil)  0.052798    0.336754
# 10        (garlic cloves)           (salt)  0.075300    0.480276
# 11  (ground black pepper)           (salt)  0.068738    0.571488
# 12            (olive oil)         (onions)  0.055489    0.276879
# 13               (onions)      (olive oil)  0.055489    0.276844
# 14            (olive oil)           (salt)  0.105018    0.524025
# 15                 (salt)      (olive oil)  0.105018    0.231438
# 16               (onions)           (salt)  0.110424    0.550928
# 17                 (salt)         (onions)  0.110424    0.243351
# 18                 (salt)         (pepper)  0.096646    0.212988
# 19               (pepper)           (salt)  0.096646    0.866156
# 20                (sugar)           (salt)  0.076960    0.475754
# 21        (vegetable oil)           (salt)  0.052823    0.479133
# 22                 (salt)          (water)  0.099563    0.219415
# 23                (water)           (salt)  0.099563    0.531045

# %%
# plot support vs confidence graph 
support=rules['support'].values
confidence=rules['confidence'].values
for i in range (len(support)):
   support[i] = support[i] + 0.0025 * (random.randint(1,10) - 5) 
   confidence[i] = confidence[i] + 0.0025 * (random.randint(1,10) - 5)
 
plt.scatter(support, confidence, alpha=0.5, marker="*")
plt.xlabel('support')
plt.ylabel('confidence') 
plt.show()

# %%
# define function to create association rule graph
def draw_graph(rules, num_rules):
  G1 = nx.DiGraph()
   
  color_map=[]
  N = 50
  colors = np.random.rand(N)       
   
  for i in range(num_rules): 
    G1.add_node("R"+str(i))
    
    for a in rules.iloc[i]['antecedents']:
        G1.add_node(a)
        G1.add_edge(a, "R"+str(i), color=colors[i] , weight = 2)
       
    for c in rules.iloc[i]['consequents']:
        G1.add_node(c)
        G1.add_edge("R"+str(i), c, color=colors[i],  weight=2)
   
  edges = G1.edges()
  colors = [G1[u][v]['color'] for u,v in edges]
  weights = [G1[u][v]['weight'] for u,v in edges]
 
  pos = nx.spring_layout(G1, k=16, scale=1)
  nx.draw(G1, pos, edges=edges, node_color = color_map, edge_color=colors, width=weights, font_size=16, with_labels=False)            
   
  for p in pos:  # raise text positions
    pos[p][1] += 0.07
  nx.draw_networkx_labels(G1, pos)
  plt.show()

# %%
draw_graph(rules, 10)
# Out:
# frozenset({'all-purpose flour'})
# frozenset({'butter'})
# frozenset({'olive oil'})
# frozenset({'garlic'})
# frozenset({'garlic'})
# frozenset({'onions'})
# frozenset({'garlic'})
# frozenset({'salt'})
# frozenset({'olive oil'})
# frozenset({'garlic cloves'})
