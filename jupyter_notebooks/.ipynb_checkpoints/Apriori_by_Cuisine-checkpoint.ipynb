# %%
# Import libraries
import pandas as pd
import numpy as np
import networkx as nx  
import json
import random
import collections
import matplotlib.pyplot as plt
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

# %%
# read in JSON into dataframe
def preprocess():
    with open('../data/train.json') as json_file:
        df = pd.read_json(json_file, orient='columns')
        cuisines = df.cuisine.unique()
    return df, cuisines

# %%
# get all the recipes for a cuisine
def get_cuisine_data(df, cuisine):
    data = df[df['cuisine']==cuisine].ingredients
    return data

# %%
# create a dictionary mapping cuisine to all recipes of that cuisine type
def create_cuisine_dict(df, cuisines):
    cuisine_dict = {}
    for cuisine in cuisines:
        cuisine_dict["{0}".format(cuisine)] = get_cuisine_data(df, cuisine)
    return cuisine_dict

# %%
# remove the 12 most common ingredients
def remove_common_ingredients(cuisine_dict):
    common_ingredients = ['salt','olive oil', 'onions', 'water', 'garlic', 'sugar', 'garlic cloves', 'butter', 'ground black pepper', 'all-purpose flour', 'pepper', 'vegetable oil']
    for cuisine in dataset[1]:
        for recipe in cuisine_dict[cuisine]:
            for word in list(recipe):
                if word in common_ingredients:
                    recipe.remove(word)
    return cuisine_dict

# %%
# define function to create association rule graph
def draw_graph(rules, num_rules):
    graph = nx.DiGraph()

    color_map=[]
    N = 50
    colors = np.random.rand(N)       

    for i in range(num_rules): 
        graph.add_node("R"+str(i))

        for a in rules.iloc[i]['antecedents']:
            graph.add_node(a)
            graph.add_edge(a, "R"+str(i), color=colors[i] , weight = 2)

        for c in rules.iloc[i]['consequents']:
            graph.add_node(c)
            graph.add_edge("R"+str(i), c, color=colors[i],  weight=2)

    edges = graph.edges()
    colors = [graph[u][v]['color'] for u,v in edges]
    weights = [graph[u][v]['weight'] for u,v in edges]

    pos = nx.spring_layout(graph, k=16, scale=1)
    nx.draw(graph, pos, edges=edges, node_color = color_map, edge_color=colors, width=weights, font_size=16, with_labels=False)            

    for p in pos:  # raise text positions
        pos[p][1] += 0.07
    nx.draw_networkx_labels(graph, pos)
    plt.show()

# %%
def create_rules(cuisine_data):
    # encode data for apriori algo
    encoder = TransactionEncoder()
    fit_data = encoder.fit(cuisine_data).transform(cuisine_data)
    encoded_df = pd.DataFrame(fit_data, columns=encoder.columns_)
    
    # define frequent itemsets
    frequent_itemsets = apriori(encoded_df, min_support=0.05, use_colnames=True).sort_values('support', ascending=False)
#     print(frequent_itemsets)
    
    # create association rules
    rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.2).sort_values('confidence', ascending=False)
#     print(rules[['antecedents', 'consequents', 'support', 'confidence']])
    
    # draw graph
    draw_graph(rules, 10)

# %%
# call all functions 
dataset = preprocess()
cuisine_dict = create_cuisine_dict(dataset[0], dataset[1])
# filtered = remove_common_ingredients(cuisine_dict)
for cuisine in dataset[1]:
    create_rules(cuisine_dict[cuisine])
    print(cuisine)
# Out:
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:585: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   and cb.iterable(edge_color) \
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:595: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   for c in edge_color]):
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:676: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cb.iterable(node_size):  # many node sizes
# greek
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:585: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   and cb.iterable(edge_color) \
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:595: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   for c in edge_color]):
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:676: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cb.iterable(node_size):  # many node sizes
# southern_us
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:585: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   and cb.iterable(edge_color) \
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:595: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   for c in edge_color]):
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:676: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cb.iterable(node_size):  # many node sizes
# filipino
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:585: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   and cb.iterable(edge_color) \
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:595: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   for c in edge_color]):
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:676: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cb.iterable(node_size):  # many node sizes
# indian
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:585: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   and cb.iterable(edge_color) \
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:595: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   for c in edge_color]):
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:676: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cb.iterable(node_size):  # many node sizes
# jamaican
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:585: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   and cb.iterable(edge_color) \
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:595: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   for c in edge_color]):
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:676: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cb.iterable(node_size):  # many node sizes
# spanish
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:585: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   and cb.iterable(edge_color) \
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:595: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   for c in edge_color]):
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:676: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cb.iterable(node_size):  # many node sizes
# italian
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:585: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   and cb.iterable(edge_color) \
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:595: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   for c in edge_color]):
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:676: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cb.iterable(node_size):  # many node sizes
# mexican
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:585: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   and cb.iterable(edge_color) \
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:595: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   for c in edge_color]):
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:676: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cb.iterable(node_size):  # many node sizes
# chinese
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:585: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   and cb.iterable(edge_color) \
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:595: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   for c in edge_color]):
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:676: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cb.iterable(node_size):  # many node sizes
# british
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:585: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   and cb.iterable(edge_color) \
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:595: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   for c in edge_color]):
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:676: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cb.iterable(node_size):  # many node sizes
# thai
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:585: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   and cb.iterable(edge_color) \
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:595: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   for c in edge_color]):
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:676: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cb.iterable(node_size):  # many node sizes
# vietnamese
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:585: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   and cb.iterable(edge_color) \
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:595: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   for c in edge_color]):
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:676: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cb.iterable(node_size):  # many node sizes
# cajun_creole
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:585: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   and cb.iterable(edge_color) \
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:595: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   for c in edge_color]):
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:676: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cb.iterable(node_size):  # many node sizes
# brazilian
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:585: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   and cb.iterable(edge_color) \
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:595: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   for c in edge_color]):
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:676: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cb.iterable(node_size):  # many node sizes
# french
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:585: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   and cb.iterable(edge_color) \
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:595: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   for c in edge_color]):
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:676: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cb.iterable(node_size):  # many node sizes
# japanese
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:585: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   and cb.iterable(edge_color) \
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:595: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   for c in edge_color]):
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:676: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cb.iterable(node_size):  # many node sizes
# irish
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:585: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   and cb.iterable(edge_color) \
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:595: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   for c in edge_color]):
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:676: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cb.iterable(node_size):  # many node sizes
# korean
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:585: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   and cb.iterable(edge_color) \
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:595: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   for c in edge_color]):
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:676: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cb.iterable(node_size):  # many node sizes
# moroccan
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:585: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   and cb.iterable(edge_color) \
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:595: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   for c in edge_color]):
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:676: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cb.iterable(node_size):  # many node sizes
# russian

# %%
# greek
create_rules(filtered['greek'])
print('greek')
# Out:
#      support                                     itemsets
# 4   0.226383                              (dried oregano)
# 9   0.214468                       (feta cheese crumbles)
# 7   0.194894                     (extra-virgin olive oil)
# 12  0.188936                          (fresh lemon juice)
# 8   0.162553                                (feta cheese)
# 3   0.159149                                   (cucumber)
# 26  0.158298                               (purple onion)
# 23  0.154894                                (lemon juice)
# 28  0.132766                                   (tomatoes)
# 22  0.109787                                      (lemon)
# 14  0.096170                              (fresh parsley)
# 11  0.091915                                 (fresh dill)
# 27  0.084255                           (red wine vinegar)
# 33  0.075745        (dried oregano, feta cheese crumbles)
# 0   0.075745                               (black pepper)
# 35  0.074894  (extra-virgin olive oil, fresh lemon juice)
# 20  0.072340                                (kosher salt)
# 15  0.071489                               (greek yogurt)
# 13  0.069787                              (fresh oregano)
# 6   0.068085                                       (eggs)
# 34  0.066383                (purple onion, dried oregano)
# 19  0.066383                                   (kalamata)
# 31  0.065532                     (cucumber, purple onion)
# 16  0.062128                            (ground cinnamon)
# 36  0.061277         (purple onion, feta cheese crumbles)
# 21  0.061277                                 (large eggs)
# 25  0.059574                     (pitted kalamata olives)
# 24  0.057872                              (minced garlic)
# 1   0.057872                         (chopped fresh mint)
# 17  0.057872                                (ground lamb)
# 2   0.057021                              (cooking spray)
# 18  0.057021                                      (honey)
# 30  0.056170                    (cucumber, dried oregano)
# 10  0.055319                          (flat leaf parsley)
# 5   0.051915                                   (eggplant)
# 29  0.050213                            (unsalted butter)
# 32  0.050213      (extra-virgin olive oil, dried oregano)
#                  antecedents               consequents   support  confidence
# 0            (dried oregano)    (feta cheese crumbles)  0.075745    0.334586
# 1     (feta cheese crumbles)           (dried oregano)  0.075745    0.353175
# 2   (extra-virgin olive oil)       (fresh lemon juice)  0.074894    0.384279
# 3        (fresh lemon juice)  (extra-virgin olive oil)  0.074894    0.396396
# 4             (purple onion)           (dried oregano)  0.066383    0.419355
# 5            (dried oregano)            (purple onion)  0.066383    0.293233
# 6                 (cucumber)            (purple onion)  0.065532    0.411765
# 7             (purple onion)                (cucumber)  0.065532    0.413978
# 8             (purple onion)    (feta cheese crumbles)  0.061277    0.387097
# 9     (feta cheese crumbles)            (purple onion)  0.061277    0.285714
# 10                (cucumber)           (dried oregano)  0.056170    0.352941
# 11           (dried oregano)                (cucumber)  0.056170    0.248120
# 12  (extra-virgin olive oil)           (dried oregano)  0.050213    0.257642
# 13           (dried oregano)  (extra-virgin olive oil)  0.050213    0.221805
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:585: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   and cb.iterable(edge_color) \
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:595: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   for c in edge_color]):
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:676: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cb.iterable(node_size):  # many node sizes
# greek

# %%
# southern us
create_rules(filtered['southern_us'])
print('southern_us')
# Out:
#      support                          itemsets
# 12  0.172685                      (large eggs)
# 0   0.168750                   (baking powder)
# 14  0.151620                 (unsalted butter)
# 13  0.149306                            (milk)
# 4   0.146759                      (buttermilk)
# 6   0.143981                            (eggs)
# 15  0.107407                 (vanilla extract)
# 1   0.103472                     (baking soda)
# 11  0.081019                     (kosher salt)
# 18  0.068519       (baking powder, buttermilk)
# 17  0.066204      (baking powder, baking soda)
# 2   0.062731                    (black pepper)
# 7   0.062269                           (flour)
# 21  0.061574         (buttermilk, baking soda)
# 9   0.060417                (granulated sugar)
# 3   0.060417                     (brown sugar)
# 20  0.060417  (unsalted butter, baking powder)
# 10  0.057407                 (ground cinnamon)
# 8   0.055093                   (garlic powder)
# 5   0.053935                  (cayenne pepper)
# 19  0.051157       (baking powder, large eggs)
# 16  0.050000                (yellow corn meal)
#          antecedents        consequents   support  confidence
# 0    (baking powder)       (buttermilk)  0.068519    0.406036
# 1       (buttermilk)    (baking powder)  0.068519    0.466877
# 2    (baking powder)      (baking soda)  0.066204    0.392318
# 3      (baking soda)    (baking powder)  0.066204    0.639821
# 4       (buttermilk)      (baking soda)  0.061574    0.419558
# 5      (baking soda)       (buttermilk)  0.061574    0.595078
# 6  (unsalted butter)    (baking powder)  0.060417    0.398473
# 7    (baking powder)  (unsalted butter)  0.060417    0.358025
# 8    (baking powder)       (large eggs)  0.051157    0.303155
# 9       (large eggs)    (baking powder)  0.051157    0.296247
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:585: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   and cb.iterable(edge_color) \
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:595: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   for c in edge_color]):
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:676: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cb.iterable(node_size):  # many node sizes
# southern_us

# %%
# filipino
create_rules(filtered['filipino'])
print('filipino')
# Out:
#      support                  itemsets
# 19  0.332450               (soy sauce)
# 14  0.219868                     (oil)
# 3   0.169536                 (carrots)
# 9   0.129801              (fish sauce)
# 0   0.128477              (bay leaves)
# 8   0.123179                    (eggs)
# 6   0.121854             (cooking oil)
# 1   0.107285             (brown sugar)
# 5   0.098013            (coconut milk)
# 24  0.092715   (soy sauce, bay leaves)
# 11  0.086093            (green onions)
# 10  0.086093                  (ginger)
# 21  0.086093                 (vinegar)
# 25  0.084768      (soy sauce, carrots)
# 28  0.080795          (soy sauce, oil)
# 7   0.075497             (corn starch)
# 20  0.071523                (tomatoes)
# 16  0.066225                (potatoes)
# 23  0.064901           (white vinegar)
# 12  0.062252             (ground pork)
# 27  0.058278         (oil, fish sauce)
# 15  0.058278                    (pork)
# 22  0.056954             (white sugar)
# 29  0.054305      (soy sauce, vinegar)
# 17  0.052980         (red bell pepper)
# 4   0.052980                 (chicken)
# 18  0.051656                  (shrimp)
# 26  0.051656  (soy sauce, cooking oil)
# 13  0.050331                   (lemon)
# 2   0.050331                 (cabbage)
#       antecedents    consequents   support  confidence
# 0     (soy sauce)   (bay leaves)  0.092715    0.278884
# 1    (bay leaves)    (soy sauce)  0.092715    0.721649
# 2     (soy sauce)      (carrots)  0.084768    0.254980
# 3       (carrots)    (soy sauce)  0.084768    0.500000
# 4     (soy sauce)          (oil)  0.080795    0.243028
# 5           (oil)    (soy sauce)  0.080795    0.367470
# 6           (oil)   (fish sauce)  0.058278    0.265060
# 7    (fish sauce)          (oil)  0.058278    0.448980
# 8     (soy sauce)      (vinegar)  0.054305    0.163347
# 9       (vinegar)    (soy sauce)  0.054305    0.630769
# 10    (soy sauce)  (cooking oil)  0.051656    0.155378
# 11  (cooking oil)    (soy sauce)  0.051656    0.423913
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:585: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   and cb.iterable(edge_color) \
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:595: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   for c in edge_color]):
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:676: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cb.iterable(node_size):  # many node sizes
# filipino

# %%
# indian
create_rules(filtered['indian'])
print('indian')
# Out:
#      support                          itemsets
# 22  0.287046                    (garam masala)
# 30  0.242424                 (ground turmeric)
# 18  0.232101                      (cumin seed)
# 29  0.227439                    (ground cumin)
# 35  0.181818                             (oil)
# 25  0.175158                          (ginger)
# 44  0.173493                        (tomatoes)
# 45  0.163836                         (tumeric)
# 5   0.161505                    (chili powder)
# 26  0.161172                   (green chilies)
# 20  0.134199                    (curry powder)
# 28  0.126540                (ground coriander)
# 21  0.126207                    (fresh ginger)
# 9   0.117549                 (cilantro leaves)
# 12  0.101898                           (clove)
# 64  0.094572   (ground turmeric, garam masala)
# 56  0.092241     (ground turmeric, cumin seed)
# 24  0.090909                            (ghee)
# 32  0.090243                     (lemon juice)
# 74  0.085914  (ground cumin, ground coriander)
# 75  0.085248   (ground cumin, ground turmeric)
# 11  0.085248                 (cinnamon sticks)
# 63  0.084915      (ground cumin, garam masala)
# 34  0.084582                   (mustard seeds)
# 39  0.083583                        (potatoes)
# 31  0.083583                     (kosher salt)
# 4   0.082917                  (cayenne pepper)
# 53  0.082584        (garam masala, cumin seed)
# 66  0.082251          (tomatoes, garam masala)
# 0   0.081918                    (basmati rice)
# ..       ...                               ...
# 62  0.061272     (green chilies, garam masala)
# 71  0.060273  (green chilies, ground turmeric)
# 54  0.060273              (ginger, cumin seed)
# 55  0.060273       (green chilies, cumin seed)
# 49  0.059607               (chili powder, oil)
# 17  0.059274                           (cumin)
# 27  0.057942                 (ground cardamom)
# 42  0.056943                (red chili powder)
# 40  0.056610                    (purple onion)
# 68  0.054945           (green chilies, ginger)
# 41  0.054945               (red chili peppers)
# 79  0.054612                   (oil, tomatoes)
# 1   0.053613                    (black pepper)
# 50  0.053613          (chili powder, tomatoes)
# 73  0.053280         (green chilies, tomatoes)
# 43  0.053280                    (tomato paste)
# 2   0.052947                      (canola oil)
# 69  0.052947         (ginger, ground turmeric)
# 70  0.052614                 (ginger, tumeric)
# 33  0.052614                            (milk)
# 52  0.052614            (oil, cilantro leaves)
# 60  0.052281      (garam masala, fresh ginger)
# 10  0.051948                        (cinnamon)
# 8   0.051948                        (cilantro)
# 37  0.051615             (peeled fresh ginger)
# 6   0.051615                (chopped cilantro)
# 59  0.051615             (cumin seed, tumeric)
# 76  0.051282          (ground cumin, tomatoes)
# 51  0.050283  (green chilies, cilantro leaves)
# 57  0.050283                 (oil, cumin seed)
#
# [80 rows x 2 columns]
#            antecedents         consequents   support  confidence
# 0    (ground turmeric)      (garam masala)  0.094572    0.390110
# 1       (garam masala)   (ground turmeric)  0.094572    0.329466
# 2    (ground turmeric)        (cumin seed)  0.092241    0.380495
# 3         (cumin seed)   (ground turmeric)  0.092241    0.397418
# 4       (ground cumin)  (ground coriander)  0.085914    0.377745
# 5   (ground coriander)      (ground cumin)  0.085914    0.678947
# 6       (ground cumin)   (ground turmeric)  0.085248    0.374817
# 7    (ground turmeric)      (ground cumin)  0.085248    0.351648
# 8       (ground cumin)      (garam masala)  0.084915    0.373353
# 9       (garam masala)      (ground cumin)  0.084915    0.295824
# 10      (garam masala)        (cumin seed)  0.082584    0.287703
# 11        (cumin seed)      (garam masala)  0.082584    0.355811
# 12          (tomatoes)      (garam masala)  0.082251    0.474088
# 13      (garam masala)          (tomatoes)  0.082251    0.286543
# 14      (chili powder)      (garam masala)  0.080919    0.501031
# 15      (garam masala)      (chili powder)  0.080919    0.281903
# 16            (ginger)      (garam masala)  0.079587    0.454373
# 17      (garam masala)            (ginger)  0.079587    0.277262
# 18               (oil)     (green chilies)  0.077256    0.424908
# 19     (green chilies)               (oil)  0.077256    0.479339
# 20   (ground turmeric)          (tomatoes)  0.072927    0.300824
# 21          (tomatoes)   (ground turmeric)  0.072927    0.420345
# 22               (oil)      (garam masala)  0.072594    0.399267
# 23      (garam masala)               (oil)  0.072594    0.252900
# 24      (chili powder)   (ground turmeric)  0.071595    0.443299
# 25   (ground turmeric)      (chili powder)  0.071595    0.295330
# 26      (garam masala)           (tumeric)  0.070929    0.247100
# 27           (tumeric)      (garam masala)  0.070929    0.432927
# 28          (tomatoes)        (cumin seed)  0.063936    0.368522
# 29        (cumin seed)          (tomatoes)  0.063936    0.275466
# ..                 ...                 ...       ...         ...
# 36            (ginger)        (cumin seed)  0.060273    0.344106
# 37        (cumin seed)            (ginger)  0.060273    0.259684
# 38     (green chilies)        (cumin seed)  0.060273    0.373967
# 39        (cumin seed)     (green chilies)  0.060273    0.259684
# 40      (chili powder)               (oil)  0.059607    0.369072
# 41               (oil)      (chili powder)  0.059607    0.327839
# 42     (green chilies)            (ginger)  0.054945    0.340909
# 43            (ginger)     (green chilies)  0.054945    0.313688
# 44               (oil)          (tomatoes)  0.054612    0.300366
# 45          (tomatoes)               (oil)  0.054612    0.314779
# 46      (chili powder)          (tomatoes)  0.053613    0.331959
# 47          (tomatoes)      (chili powder)  0.053613    0.309021
# 48     (green chilies)          (tomatoes)  0.053280    0.330579
# 49          (tomatoes)     (green chilies)  0.053280    0.307102
# 50            (ginger)   (ground turmeric)  0.052947    0.302281
# 51   (ground turmeric)            (ginger)  0.052947    0.218407
# 52            (ginger)           (tumeric)  0.052614    0.300380
# 53           (tumeric)            (ginger)  0.052614    0.321138
# 54               (oil)   (cilantro leaves)  0.052614    0.289377
# 55   (cilantro leaves)               (oil)  0.052614    0.447592
# 56      (garam masala)      (fresh ginger)  0.052281    0.182135
# 57      (fresh ginger)      (garam masala)  0.052281    0.414248
# 58        (cumin seed)           (tumeric)  0.051615    0.222382
# 59           (tumeric)        (cumin seed)  0.051615    0.315041
# 60      (ground cumin)          (tomatoes)  0.051282    0.225476
# 61          (tomatoes)      (ground cumin)  0.051282    0.295585
# 62     (green chilies)   (cilantro leaves)  0.050283    0.311983
# 63   (cilantro leaves)     (green chilies)  0.050283    0.427762
# 64               (oil)        (cumin seed)  0.050283    0.276557
# 65        (cumin seed)               (oil)  0.050283    0.216643
#
# [66 rows x 4 columns]
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:585: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   and cb.iterable(edge_color) \
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:595: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   for c in edge_color]):
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:676: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cb.iterable(node_size):  # many node sizes
# indian

# %%
# jamaican
create_rules(filtered['jamaican'])
print('jamaican')
# Out:
#      support                                           itemsets
# 21  0.243346                                  (ground allspice)
# 35  0.211027                                        (scallions)
# 12  0.199620                                      (dried thyme)
# 2   0.195817                                     (black pepper)
# 22  0.142586                                  (ground cinnamon)
# 3   0.136882                                      (brown sugar)
# 38  0.136882                                            (thyme)
# 8   0.134981                                     (coconut milk)
# 37  0.127376                                        (soy sauce)
# 10  0.125475                                     (curry powder)
# 20  0.123574                                     (green onions)
# 25  0.115970                                    (ground nutmeg)
# 17  0.112167                                      (fresh thyme)
# 42  0.112167                     (dried thyme, ground allspice)
# 0   0.100760                                         (allspice)
# 28  0.093156                                             (lime)
# 44  0.093156                 (ground cinnamon, ground allspice)
# 29  0.091255                                       (lime juice)
# 14  0.089354                                            (flour)
# 7   0.085551                                         (cinnamon)
# 4   0.083650                                          (carrots)
# 45  0.079848                   (ground nutmeg, ground allspice)
# 5   0.079848                                   (cayenne pepper)
# 13  0.077947                                             (eggs)
# 36  0.074144                              (scotch bonnet chile)
# 32  0.072243                                              (oil)
# 1   0.072243                                    (baking powder)
# 18  0.072243                                    (garlic powder)
# 39  0.070342                                         (tomatoes)
# 47  0.070342                       (soy sauce, ground allspice)
# 31  0.070342                                           (nutmeg)
# 6   0.068441                                          (chicken)
# 49  0.066540                                 (scallions, thyme)
# 48  0.066540                   (ground nutmeg, ground cinnamon)
# 27  0.062738                                      (kosher salt)
# 24  0.062738                                    (ground ginger)
# 16  0.060837                                 (fresh lime juice)
# 9   0.058935                                       (cold water)
# 40  0.058935                              (black pepper, thyme)
# 15  0.058935                                     (fresh ginger)
# 34  0.055133                                  (red bell pepper)
# 46  0.055133                       (scallions, ground allspice)
# 33  0.053232                                     (onion powder)
# 26  0.053232                                 (jalapeno chilies)
# 11  0.053232                                         (dark rum)
# 19  0.053232                                           (ginger)
# 50  0.053232  (ground nutmeg, ground cinnamon, ground allspice)
# 43  0.051331                           (scallions, fresh thyme)
# 41  0.051331                  (cayenne pepper, ground allspice)
# 30  0.051331                                             (milk)
# 23  0.051331                                    (ground cloves)
#                            antecedents                         consequents  \
# 0                        (dried thyme)                   (ground allspice)
# 1                    (ground allspice)                       (dried thyme)
# 2                    (ground cinnamon)                   (ground allspice)
# 3                    (ground allspice)                   (ground cinnamon)
# 4                      (ground nutmeg)                   (ground allspice)
# 5                    (ground allspice)                     (ground nutmeg)
# 6                          (soy sauce)                   (ground allspice)
# 7                    (ground allspice)                         (soy sauce)
# 8                          (scallions)                             (thyme)
# 9                              (thyme)                         (scallions)
# 10                     (ground nutmeg)                   (ground cinnamon)
# 11                   (ground cinnamon)                     (ground nutmeg)
# 12                      (black pepper)                             (thyme)
# 13                             (thyme)                      (black pepper)
# 14                         (scallions)                   (ground allspice)
# 15                   (ground allspice)                         (scallions)
# 16    (ground nutmeg, ground cinnamon)                   (ground allspice)
# 17    (ground nutmeg, ground allspice)                   (ground cinnamon)
# 18  (ground cinnamon, ground allspice)                     (ground nutmeg)
# 19                     (ground nutmeg)  (ground cinnamon, ground allspice)
# 20                   (ground cinnamon)    (ground nutmeg, ground allspice)
# 21                   (ground allspice)    (ground nutmeg, ground cinnamon)
# 22                         (scallions)                       (fresh thyme)
# 23                       (fresh thyme)                         (scallions)
# 24                    (cayenne pepper)                   (ground allspice)
# 25                   (ground allspice)                    (cayenne pepper)
#
#      support  confidence
# 0   0.112167    0.561905
# 1   0.112167    0.460938
# 2   0.093156    0.653333
# 3   0.093156    0.382812
# 4   0.079848    0.688525
# 5   0.079848    0.328125
# 6   0.070342    0.552239
# 7   0.070342    0.289062
# 8   0.066540    0.315315
# 9   0.066540    0.486111
# 10  0.066540    0.573770
# 11  0.066540    0.466667
# 12  0.058935    0.300971
# 13  0.058935    0.430556
# 14  0.055133    0.261261
# 15  0.055133    0.226562
# 16  0.053232    0.800000
# 17  0.053232    0.666667
# 18  0.053232    0.571429
# 19  0.053232    0.459016
# 20  0.053232    0.373333
# 21  0.053232    0.218750
# 22  0.051331    0.243243
# 23  0.051331    0.457627
# 24  0.051331    0.642857
# 25  0.051331    0.210938
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:585: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   and cb.iterable(edge_color) \
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:595: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   for c in edge_color]):
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:676: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cb.iterable(node_size):  # many node sizes
# jamaican

# %%
# spanish
create_rules(filtered['spanish'])
print('spanish')
# Out:
#      support                               itemsets
# 6   0.257836               (extra-virgin olive oil)
# 24  0.152679                             (tomatoes)
# 20  0.143579                      (red bell pepper)
# 12  0.121335                          (kosher salt)
# 13  0.117290                           (large eggs)
# 9   0.101112                        (fresh parsley)
# 4   0.100101                       (dry white wine)
# 22  0.096057                      (saffron threads)
# 5   0.088979                                 (eggs)
# 17  0.083923                              (paprika)
# 7   0.082912                    (flat leaf parsley)
# 15  0.072801                                (lemon)
# 14  0.071790                  (large garlic cloves)
# 0   0.071790                         (black pepper)
# 23  0.069767                       (sherry vinegar)
# 10  0.067745                    (green bell pepper)
# 3   0.062690                       (diced tomatoes)
# 18  0.060667                             (potatoes)
# 2   0.058645                             (cucumber)
# 21  0.057634                     (red wine vinegar)
# 1   0.055612                        (chopped onion)
# 11  0.055612                         (ground cumin)
# 19  0.055612                         (purple onion)
# 8   0.055612                    (fresh lemon juice)
# 25  0.054601  (extra-virgin olive oil, kosher salt)
# 16  0.052578                        (minced garlic)
#                 antecedents               consequents   support  confidence
# 0  (extra-virgin olive oil)             (kosher salt)  0.054601    0.211765
# 1             (kosher salt)  (extra-virgin olive oil)  0.054601    0.450000
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-251-31827de3a268> in <module>
#       1 # spanish
# ----> 2 create_rules(filtered['spanish'])
#       3 print('spanish')
#
# <ipython-input-203-6b0b03a3f5b0> in create_rules(cuisine_data)
#      14
#      15     # draw graph
# ---> 16     draw_graph(rules, 10)
#
# <ipython-input-202-98811bab647f> in draw_graph(rules, num_rules)
#      10         graph.add_node("R"+str(i))
#      11
# ---> 12         for a in rules.iloc[i]['antecedents']:
#      13             graph.add_node(a)
#      14             graph.add_edge(a, "R"+str(i), color=colors[i] , weight = 2)
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1498
#    1499             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1500             return self._getitem_axis(maybe_callable, axis=axis)
#    1501
#    1502     def _is_scalar_access(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    2228
#    2229             # validate the location
# -> 2230             self._validate_integer(key, axis)
#    2231
#    2232             return self._get_loc(key, axis=axis)
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_integer(self, key, axis)
#    2137         len_axis = len(self.obj._get_axis(axis))
#    2138         if key >= len_axis or key < -len_axis:
# -> 2139             raise IndexError("single positional indexer is out-of-bounds")
#    2140
#    2141     def _getitem_tuple(self, tup):
#
# IndexError: single positional indexer is out-of-bounds

# %%
# italian
create_rules(filtered['italian'])
print('italian')
# Out:
#      support                      itemsets
# 13  0.201454      (grated parmesan cheese)
# 8   0.173769      (extra-virgin olive oil)
# 10  0.100408                 (fresh basil)
# 6   0.083950              (dry white wine)
# 14  0.083695                 (kosher salt)
# 0   0.081143                (black pepper)
# 12  0.080505               (fresh parsley)
# 7   0.079995                        (eggs)
# 5   0.079867               (dried oregano)
# 15  0.079740                  (large eggs)
# 19  0.076678                    (tomatoes)
# 9   0.075019           (flat leaf parsley)
# 20  0.071957             (unsalted butter)
# 1   0.062644               (cooking spray)
# 17  0.060475             (parmesan cheese)
# 11  0.060092           (fresh lemon juice)
# 3   0.054733              (diced tomatoes)
# 4   0.054223                 (dried basil)
# 2   0.053330          (crushed red pepper)
# 18  0.052564  (shredded mozzarella cheese)
# 16  0.050523           (mozzarella cheese)
# Empty DataFrame
# Columns: [antecedents, consequents, support, confidence]
# Index: []
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-252-c3ce59a340a9> in <module>
#       1 # italian
# ----> 2 create_rules(filtered['italian'])
#       3 print('italian')
#
# <ipython-input-203-6b0b03a3f5b0> in create_rules(cuisine_data)
#      14
#      15     # draw graph
# ---> 16     draw_graph(rules, 10)
#
# <ipython-input-202-98811bab647f> in draw_graph(rules, num_rules)
#      10         graph.add_node("R"+str(i))
#      11
# ---> 12         for a in rules.iloc[i]['antecedents']:
#      13             graph.add_node(a)
#      14             graph.add_edge(a, "R"+str(i), color=colors[i] , weight = 2)
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1498
#    1499             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1500             return self._getitem_axis(maybe_callable, axis=axis)
#    1501
#    1502     def _is_scalar_access(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    2228
#    2229             # validate the location
# -> 2230             self._validate_integer(key, axis)
#    2231
#    2232             return self._get_loc(key, axis=axis)
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_integer(self, key, axis)
#    2137         len_axis = len(self.obj._get_axis(axis))
#    2138         if key >= len_axis or key < -len_axis:
# -> 2139             raise IndexError("single positional indexer is out-of-bounds")
#    2140
#    2141     def _getitem_tuple(self, tup):
#
# IndexError: single positional indexer is out-of-bounds

# %%
# mexican
create_rules(cuisine_dict['mexican'])
print('mexican')
# Out:
#      support                      itemsets
# 21  0.209071                (ground cumin)
# 5   0.191985                (chili powder)
# 22  0.178006            (jalapeno chilies)
# 30  0.167133                  (sour cream)
# 0   0.162007                     (avocado)
# 10  0.146940              (corn tortillas)
# 28  0.143368                       (salsa)
# 7   0.140727      (chopped cilantro fresh)
# 31  0.135290                    (tomatoes)
# 15  0.127058             (flour tortillas)
# 1   0.125971                 (black beans)
# 24  0.113700                        (lime)
# 17  0.100342            (fresh lime juice)
# 19  0.099099                (green onions)
# 11  0.097080                       (cumin)
# 26  0.095993                (purple onion)
# 8   0.095837                    (cilantro)
# 23  0.093352                 (kosher salt)
# 29  0.093041     (shredded cheddar cheese)
# 12  0.084498              (diced tomatoes)
# 25  0.083566                  (lime juice)
# 34  0.083566  (ground cumin, chili powder)
# 13  0.080460               (dried oregano)
# 18  0.075023               (garlic powder)
# 16  0.068344              (fresh cilantro)
# 27  0.062908             (red bell pepper)
# 32  0.062908                 (white onion)
# 20  0.061820                 (ground beef)
# 4   0.061044               (chicken broth)
# 6   0.059801            (chopped cilantro)
# 2   0.059646                (black pepper)
# 33  0.054054         (chili powder, cumin)
# 35  0.052501           (sour cream, salsa)
# 9   0.050947             (cilantro leaves)
# 14  0.050637                        (eggs)
# 3   0.050482              (cayenne pepper)
#       antecedents     consequents   support  confidence
# 0  (ground cumin)  (chili powder)  0.083566    0.399703
# 1  (chili powder)  (ground cumin)  0.083566    0.435275
# 2  (chili powder)         (cumin)  0.054054    0.281553
# 3         (cumin)  (chili powder)  0.054054    0.556800
# 4    (sour cream)         (salsa)  0.052501    0.314126
# 5         (salsa)    (sour cream)  0.052501    0.366197
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-253-882d15ee1667> in <module>
#       1 # mexican
# ----> 2 create_rules(cuisine_dict['mexican'])
#       3 print('mexican')
#
# <ipython-input-203-6b0b03a3f5b0> in create_rules(cuisine_data)
#      14
#      15     # draw graph
# ---> 16     draw_graph(rules, 10)
#
# <ipython-input-202-98811bab647f> in draw_graph(rules, num_rules)
#      10         graph.add_node("R"+str(i))
#      11
# ---> 12         for a in rules.iloc[i]['antecedents']:
#      13             graph.add_node(a)
#      14             graph.add_edge(a, "R"+str(i), color=colors[i] , weight = 2)
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1498
#    1499             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1500             return self._getitem_axis(maybe_callable, axis=axis)
#    1501
#    1502     def _is_scalar_access(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    2228
#    2229             # validate the location
# -> 2230             self._validate_integer(key, axis)
#    2231
#    2232             return self._get_loc(key, axis=axis)
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_integer(self, key, axis)
#    2137         len_axis = len(self.obj._get_axis(axis))
#    2138         if key >= len_axis or key < -len_axis:
# -> 2139             raise IndexError("single positional indexer is out-of-bounds")
#    2140
#    2141     def _getitem_tuple(self, tup):
#
# IndexError: single positional indexer is out-of-bounds

# %%
# chinese
create_rules(filtered['chinese'])
print('chinese')
# Out:
#      support                                          itemsets
# 33  0.509914                                       (soy sauce)
# 31  0.342312                                      (sesame oil)
# 8   0.338945                                     (corn starch)
# 13  0.234942                                    (green onions)
# 72  0.222222                           (soy sauce, sesame oil)
# 30  0.221100                                       (scallions)
# 51  0.199776                          (soy sauce, corn starch)
# 12  0.183315                                          (ginger)
# 11  0.175458                                    (fresh ginger)
# 28  0.172465                                    (rice vinegar)
# 61  0.134306                         (soy sauce, green onions)
# 71  0.131687                            (soy sauce, scallions)
# 50  0.127946                         (sesame oil, corn starch)
# 22  0.126450                                             (oil)
# 23  0.124579                                    (oyster sauce)
# 15  0.120838                                    (hoisin sauce)
# 4   0.111485                                         (carrots)
# 59  0.108492                               (soy sauce, ginger)
# 10  0.107744                                            (eggs)
# 69  0.107744                         (soy sauce, rice vinegar)
# 24  0.104751                                      (peanut oil)
# 56  0.098765                         (soy sauce, fresh ginger)
# 70  0.097643                           (scallions, sesame oil)
# 60  0.095773                        (sesame oil, green onions)
# 19  0.095024                                 (light soy sauce)
# 45  0.092780                       (corn starch, green onions)
# 0   0.092406                                   (Shaoxing wine)
# 16  0.090161                                           (honey)
# 2   0.087916                                     (brown sugar)
# 49  0.087916                          (scallions, corn starch)
# ..       ...                                               ...
# 3   0.066218                                      (canola oil)
# 52  0.064721                                 (soy sauce, eggs)
# 65  0.063599                        (oyster sauce, sesame oil)
# 57  0.063225                               (scallions, ginger)
# 5   0.061728                                   (chicken broth)
# 36  0.061354                              (toasted sesame oil)
# 32  0.060606                                    (sesame seeds)
# 47  0.060606                       (oyster sauce, corn starch)
# 6   0.060232                                   (chicken stock)
# 42  0.060232                              (carrots, soy sauce)
# 26  0.058736                                 (red bell pepper)
# 73  0.057613            (soy sauce, corn starch, green onions)
# 75  0.055368               (soy sauce, scallions, corn starch)
# 34  0.055368                                   (spring onions)
# 41  0.055368                          (soy sauce, brown sugar)
# 18  0.054246                                      (large eggs)
# 63  0.054246                                (soy sauce, honey)
# 67  0.054246                           (soy sauce, peanut oil)
# 37  0.053498                                 (water chestnuts)
# 53  0.053124                      (green onions, fresh ginger)
# 74  0.052376            (soy sauce, corn starch, rice vinegar)
# 77  0.052376                   (soy sauce, ginger, sesame oil)
# 79  0.052376             (soy sauce, sesame oil, rice vinegar)
# 39  0.051627                        (soy sauce, Shaoxing wine)
# 40  0.051627  (boneless skinless chicken breasts, corn starch)
# 27  0.051253                               (red chili peppers)
# 54  0.050879                         (scallions, fresh ginger)
# 29  0.050505                                       (rice wine)
# 46  0.050131                                (oil, corn starch)
# 35  0.050131                            (szechwan peppercorns)
#
# [81 rows x 2 columns]
#                             antecedents               consequents   support  \
# 0                           (soy sauce)              (sesame oil)  0.222222
# 1                          (sesame oil)               (soy sauce)  0.222222
# 2                           (soy sauce)             (corn starch)  0.199776
# 3                         (corn starch)               (soy sauce)  0.199776
# 4                           (soy sauce)            (green onions)  0.134306
# 5                        (green onions)               (soy sauce)  0.134306
# 6                           (soy sauce)               (scallions)  0.131687
# 7                           (scallions)               (soy sauce)  0.131687
# 8                          (sesame oil)             (corn starch)  0.127946
# 9                         (corn starch)              (sesame oil)  0.127946
# 10                          (soy sauce)                  (ginger)  0.108492
# 11                             (ginger)               (soy sauce)  0.108492
# 12                          (soy sauce)            (rice vinegar)  0.107744
# 13                       (rice vinegar)               (soy sauce)  0.107744
# 14                       (fresh ginger)               (soy sauce)  0.098765
# 15                          (scallions)              (sesame oil)  0.097643
# 16                         (sesame oil)               (scallions)  0.097643
# 17                         (sesame oil)            (green onions)  0.095773
# 18                       (green onions)              (sesame oil)  0.095773
# 19                        (corn starch)            (green onions)  0.092780
# 20                       (green onions)             (corn starch)  0.092780
# 21                          (scallions)             (corn starch)  0.087916
# 22                        (corn starch)               (scallions)  0.087916
# 23              (soy sauce, sesame oil)             (corn starch)  0.086794
# 24             (soy sauce, corn starch)              (sesame oil)  0.086794
# 25            (sesame oil, corn starch)               (soy sauce)  0.086794
# 26                         (sesame oil)  (soy sauce, corn starch)  0.086794
# 27                        (corn starch)   (soy sauce, sesame oil)  0.086794
# 28                             (ginger)              (sesame oil)  0.081930
# 29                         (sesame oil)                  (ginger)  0.081930
# ..                                  ...                       ...       ...
# 55             (soy sauce, corn starch)            (green onions)  0.057613
# 56            (soy sauce, green onions)             (corn starch)  0.057613
# 57          (green onions, corn starch)               (soy sauce)  0.057613
# 58                       (green onions)  (soy sauce, corn starch)  0.057613
# 59               (soy sauce, scallions)             (corn starch)  0.055368
# 60             (soy sauce, corn starch)               (scallions)  0.055368
# 61             (scallions, corn starch)               (soy sauce)  0.055368
# 62                          (scallions)  (soy sauce, corn starch)  0.055368
# 63                        (brown sugar)               (soy sauce)  0.055368
# 64                              (honey)               (soy sauce)  0.054246
# 65                         (peanut oil)               (soy sauce)  0.054246
# 66                       (green onions)            (fresh ginger)  0.053124
# 67                       (fresh ginger)            (green onions)  0.053124
# 68             (soy sauce, corn starch)            (rice vinegar)  0.052376
# 69            (soy sauce, rice vinegar)             (corn starch)  0.052376
# 70          (corn starch, rice vinegar)               (soy sauce)  0.052376
# 71                       (rice vinegar)  (soy sauce, corn starch)  0.052376
# 72                  (soy sauce, ginger)              (sesame oil)  0.052376
# 73              (soy sauce, sesame oil)                  (ginger)  0.052376
# 74                 (ginger, sesame oil)               (soy sauce)  0.052376
# 75                             (ginger)   (soy sauce, sesame oil)  0.052376
# 76              (soy sauce, sesame oil)            (rice vinegar)  0.052376
# 77            (soy sauce, rice vinegar)              (sesame oil)  0.052376
# 78           (sesame oil, rice vinegar)               (soy sauce)  0.052376
# 79                       (rice vinegar)   (soy sauce, sesame oil)  0.052376
# 80                      (Shaoxing wine)               (soy sauce)  0.051627
# 81  (boneless skinless chicken breasts)             (corn starch)  0.051627
# 82                          (scallions)            (fresh ginger)  0.050879
# 83                       (fresh ginger)               (scallions)  0.050879
# 84                                (oil)             (corn starch)  0.050131
#
#     confidence
# 0     0.435803
# 1     0.649180
# 2     0.391783
# 3     0.589404
# 4     0.263390
# 5     0.571656
# 6     0.258254
# 7     0.595601
# 8     0.373770
# 9     0.377483
# 10    0.212766
# 11    0.591837
# 12    0.211299
# 13    0.624729
# 14    0.562900
# 15    0.441624
# 16    0.285246
# 17    0.279781
# 18    0.407643
# 19    0.273731
# 20    0.394904
# 21    0.397631
# 22    0.259382
# 23    0.390572
# 24    0.434457
# 25    0.678363
# 26    0.253552
# 27    0.256071
# 28    0.446939
# 29    0.239344
# ..         ...
# 55    0.288390
# 56    0.428969
# 57    0.620968
# 58    0.245223
# 59    0.420455
# 60    0.277154
# 61    0.629787
# 62    0.250423
# 63    0.629787
# 64    0.601660
# 65    0.517857
# 66    0.226115
# 67    0.302772
# 68    0.262172
# 69    0.486111
# 70    0.673077
# 71    0.303688
# 72    0.482759
# 73    0.235690
# 74    0.639269
# 75    0.285714
# 76    0.235690
# 77    0.486111
# 78    0.721649
# 79    0.303688
# 80    0.558704
# 81    0.696970
# 82    0.230118
# 83    0.289979
# 84    0.396450
#
# [85 rows x 4 columns]
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:585: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   and cb.iterable(edge_color) \
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:595: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   for c in edge_color]):
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:676: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cb.iterable(node_size):  # many node sizes
# chinese

# %%
# british
create_rules(filtered['british'])
print('british')
# Out:
#      support                          itemsets
# 9   0.251244                            (milk)
# 12  0.237562                 (unsalted butter)
# 3   0.237562                            (eggs)
# 0   0.151741                   (baking powder)
# 8   0.136816                      (large eggs)
# 6   0.114428                     (heavy cream)
# 22  0.111940                      (eggs, milk)
# 4   0.101990                           (flour)
# 1   0.090796                     (baking soda)
# 23  0.082090     (unsalted butter, large eggs)
# 10  0.080846                        (potatoes)
# 20  0.080846  (unsalted butter, baking powder)
# 7   0.074627                     (kosher salt)
# 2   0.073383                         (carrots)
# 13  0.073383                 (vanilla extract)
# 14  0.068408                  (whipping cream)
# 17  0.064677            (worcestershire sauce)
# 16  0.063433                      (whole milk)
# 19  0.058458       (baking powder, large eggs)
# 15  0.054726                     (white sugar)
# 5   0.053483                 (ground cinnamon)
# 18  0.052239      (baking powder, baking soda)
# 21  0.052239    (unsalted butter, baking soda)
# 11  0.050995                         (raisins)
#           antecedents        consequents   support  confidence
# 0              (eggs)             (milk)  0.111940    0.471204
# 1              (milk)             (eggs)  0.111940    0.445545
# 2   (unsalted butter)       (large eggs)  0.082090    0.345550
# 3        (large eggs)  (unsalted butter)  0.082090    0.600000
# 4   (unsalted butter)    (baking powder)  0.080846    0.340314
# 5     (baking powder)  (unsalted butter)  0.080846    0.532787
# 6     (baking powder)       (large eggs)  0.058458    0.385246
# 7        (large eggs)    (baking powder)  0.058458    0.427273
# 8     (baking powder)      (baking soda)  0.052239    0.344262
# 9       (baking soda)    (baking powder)  0.052239    0.575342
# 10  (unsalted butter)      (baking soda)  0.052239    0.219895
# 11      (baking soda)  (unsalted butter)  0.052239    0.575342
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:585: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   and cb.iterable(edge_color) \
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:595: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   for c in edge_color]):
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:676: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cb.iterable(node_size):  # many node sizes
# british

# %%
# thai
create_rules(filtered['thai'])
print('thai')
# Out:
#      support                        itemsets
# 16  0.406108                    (fish sauce)
# 12  0.229370                  (coconut milk)
# 48  0.215724                     (soy sauce)
# 20  0.177388              (fresh lime juice)
# 29  0.174789                          (lime)
# 23  0.165692                  (green onions)
# 46  0.152047                      (shallots)
# 27  0.149448                    (lemongrass)
# 30  0.142950                    (lime juice)
# 6   0.135153                   (brown sugar)
# 19  0.129955                  (fresh ginger)
# 39  0.119558               (red bell pepper)
# 55  0.115010      (fish sauce, coconut milk)
# 11  0.114360               (cilantro leaves)
# 7   0.113710                       (carrots)
# 36  0.107212                       (peanuts)
# 9   0.106563        (chopped cilantro fresh)
# 43  0.099415                  (rice vinegar)
# 4   0.098765                   (beansprouts)
# 58  0.088369  (fresh lime juice, fish sauce)
# 44  0.087719                     (scallions)
# 45  0.087719                    (sesame oil)
# 22  0.087070                        (ginger)
# 42  0.086420                  (rice noodles)
# 10  0.085120                      (cilantro)
# 61  0.084470              (lime, fish sauce)
# 2   0.079922          (Thai red curry paste)
# 40  0.077973             (red chili peppers)
# 62  0.077323        (fish sauce, lime juice)
# 51  0.076673      (unsweetened coconut milk)
# ..       ...                             ...
# 15  0.068876                          (eggs)
# 49  0.066277                    (thai basil)
# 59  0.066277      (fish sauce, green onions)
# 47  0.065627                        (shrimp)
# 34  0.064977                    (palm sugar)
# 33  0.064327                           (oil)
# 17  0.063028                   (fresh basil)
# 65  0.062378         (soy sauce, fish sauce)
# 50  0.059779                    (thai chile)
# 3   0.059779              (asian fish sauce)
# 35  0.059129                    (peanut oil)
# 1   0.058480               (Thai fish sauce)
# 32  0.058480                 (minced garlic)
# 28  0.057180            (light coconut milk)
# 38  0.054581                  (purple onion)
# 66  0.054581       (soy sauce, green onions)
# 26  0.053931                   (kosher salt)
# 57  0.053281            (lime, coconut milk)
# 67  0.052632          (lemongrass, shallots)
# 56  0.052632      (lemongrass, coconut milk)
# 54  0.052632   (cilantro leaves, fish sauce)
# 24  0.052632              (jalapeno chilies)
# 21  0.052632                      (galangal)
# 14  0.052632                  (curry powder)
# 8   0.051982              (chopped cilantro)
# 52  0.050682       (beansprouts, fish sauce)
# 37  0.050682           (peeled fresh ginger)
# 63  0.050032           (peanuts, fish sauce)
# 13  0.050032                      (cucumber)
# 0   0.050032                      (Sriracha)
#
# [68 rows x 2 columns]
#            antecedents         consequents   support  confidence
# 0         (fish sauce)      (coconut milk)  0.115010    0.283200
# 1       (coconut milk)        (fish sauce)  0.115010    0.501416
# 2   (fresh lime juice)        (fish sauce)  0.088369    0.498168
# 3         (fish sauce)  (fresh lime juice)  0.088369    0.217600
# 4               (lime)        (fish sauce)  0.084470    0.483271
# 5         (fish sauce)              (lime)  0.084470    0.208000
# 6         (lime juice)        (fish sauce)  0.077323    0.540909
# 7           (shallots)        (fish sauce)  0.076023    0.500000
# 8        (brown sugar)        (fish sauce)  0.072125    0.533654
# 9         (lemongrass)        (fish sauce)  0.070825    0.473913
# 10      (green onions)        (fish sauce)  0.066277    0.400000
# 11         (soy sauce)        (fish sauce)  0.062378    0.289157
# 12         (soy sauce)      (green onions)  0.054581    0.253012
# 13      (green onions)         (soy sauce)  0.054581    0.329412
# 14              (lime)      (coconut milk)  0.053281    0.304833
# 15      (coconut milk)              (lime)  0.053281    0.232295
# 16        (lemongrass)          (shallots)  0.052632    0.352174
# 17          (shallots)        (lemongrass)  0.052632    0.346154
# 18        (lemongrass)      (coconut milk)  0.052632    0.352174
# 19      (coconut milk)        (lemongrass)  0.052632    0.229462
# 20   (cilantro leaves)        (fish sauce)  0.052632    0.460227
# 21       (beansprouts)        (fish sauce)  0.050682    0.513158
# 22           (peanuts)        (fish sauce)  0.050032    0.466667
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:585: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   and cb.iterable(edge_color) \
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:595: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   for c in edge_color]):
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:676: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cb.iterable(node_size):  # many node sizes
# thai

# %%
# vietnamese
create_rules(filtered['vietnamese'])
print('vietnamese')
# Out:
#      support                         itemsets
# 13  0.475152                     (fish sauce)
# 6   0.237576                        (carrots)
# 39  0.187879                      (soy sauce)
# 37  0.183030                       (shallots)
# 34  0.163636                   (rice vinegar)
# 2   0.153939                    (beansprouts)
# 18  0.144242                   (green onions)
# 15  0.133333               (fresh lime juice)
# 24  0.128485                     (lime juice)
# 9   0.122424                (cilantro leaves)
# 11  0.121212                       (cucumber)
# 35  0.120000                      (scallions)
# 22  0.118788                     (lemongrass)
# 62  0.117576           (shallots, fish sauce)
# 23  0.117576                           (lime)
# 21  0.107879                    (kosher salt)
# 14  0.104242                   (fresh ginger)
# 36  0.103030                     (sesame oil)
# 5   0.099394                     (canola oil)
# 48  0.098182            (carrots, fish sauce)
# 45  0.096970        (beansprouts, fish sauce)
# 31  0.094545                   (rice noodles)
# 8   0.093333                       (cilantro)
# 27  0.083636                            (oil)
# 17  0.080000                         (ginger)
# 54  0.077576       (fish sauce, green onions)
# 16  0.077576                     (fresh mint)
# 25  0.077576                  (minced garlic)
# 60  0.077576       (fish sauce, rice vinegar)
# 30  0.076364              (red chili peppers)
# ..       ...                              ...
# 58  0.072727         (fish sauce, lime juice)
# 41  0.071515                     (star anise)
# 43  0.071515                     (thai chile)
# 49  0.071515          (carrots, rice vinegar)
# 53  0.071515   (fresh lime juice, fish sauce)
# 42  0.070303                     (thai basil)
# 33  0.069091                (rice vermicelli)
# 57  0.069091               (lime, fish sauce)
# 38  0.065455                         (shrimp)
# 50  0.061818             (soy sauce, carrots)
# 63  0.061818          (soy sauce, fish sauce)
# 1   0.061818               (asian fish sauce)
# 26  0.061818                    (mint leaves)
# 3   0.061818                   (black pepper)
# 47  0.060606              (carrots, cucumber)
# 44  0.060606                   (yellow onion)
# 52  0.060606    (cilantro leaves, fish sauce)
# 10  0.059394                    (corn starch)
# 28  0.058182                        (peanuts)
# 12  0.058182                         (daikon)
# 51  0.056970           (cilantro, fish sauce)
# 0   0.056970                       (Sriracha)
# 61  0.055758          (scallions, fish sauce)
# 32  0.055758                     (rice paper)
# 55  0.055758        (kosher salt, fish sauce)
# 46  0.055758         (fish sauce, canola oil)
# 29  0.054545                   (purple onion)
# 59  0.053333  (red chili peppers, fish sauce)
# 64  0.053333          (soy sauce, sesame oil)
# 40  0.052121                  (spring onions)
#
# [65 rows x 2 columns]
#             antecedents     consequents   support  confidence
# 0            (shallots)    (fish sauce)  0.117576    0.642384
# 1          (fish sauce)      (shallots)  0.117576    0.247449
# 2             (carrots)    (fish sauce)  0.098182    0.413265
# 3          (fish sauce)       (carrots)  0.098182    0.206633
# 4         (beansprouts)    (fish sauce)  0.096970    0.629921
# 5          (fish sauce)   (beansprouts)  0.096970    0.204082
# 6        (green onions)    (fish sauce)  0.077576    0.537815
# 7        (rice vinegar)    (fish sauce)  0.077576    0.474074
# 8          (lemongrass)    (fish sauce)  0.073939    0.622449
# 9          (lime juice)    (fish sauce)  0.072727    0.566038
# 10            (carrots)  (rice vinegar)  0.071515    0.301020
# 11       (rice vinegar)       (carrots)  0.071515    0.437037
# 12   (fresh lime juice)    (fish sauce)  0.071515    0.536364
# 13               (lime)    (fish sauce)  0.069091    0.587629
# 14          (soy sauce)       (carrots)  0.061818    0.329032
# 15            (carrots)     (soy sauce)  0.061818    0.260204
# 16          (soy sauce)    (fish sauce)  0.061818    0.329032
# 17            (carrots)      (cucumber)  0.060606    0.255102
# 18           (cucumber)       (carrots)  0.060606    0.500000
# 19    (cilantro leaves)    (fish sauce)  0.060606    0.495050
# 20           (cilantro)    (fish sauce)  0.056970    0.610390
# 21          (scallions)    (fish sauce)  0.055758    0.464646
# 22        (kosher salt)    (fish sauce)  0.055758    0.516854
# 23         (canola oil)    (fish sauce)  0.055758    0.560976
# 24  (red chili peppers)    (fish sauce)  0.053333    0.698413
# 25          (soy sauce)    (sesame oil)  0.053333    0.283871
# 26         (sesame oil)     (soy sauce)  0.053333    0.517647
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:585: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   and cb.iterable(edge_color) \
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:595: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   for c in edge_color]):
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:676: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cb.iterable(node_size):  # many node sizes
# vietnamese

# %%
# cajun_creole
create_rules(filtered['cajun_creole'])
print('cajun_creole')
# Out:
#      support                                itemsets
# 22  0.217335                     (green bell pepper)
# 5   0.192109                        (cayenne pepper)
# 4   0.189521                       (cajun seasoning)
# 23  0.165589                          (green onions)
# 6   0.159120                                (celery)
# 17  0.156533                           (dried thyme)
# 0   0.144890                     (andouille sausage)
# 2   0.142303                            (bay leaves)
# 14  0.139715                      (creole seasoning)
# 40  0.131953                                (shrimp)
# 20  0.124838                         (fresh parsley)
# 37  0.124191                               (paprika)
# 45  0.120310                  (worcestershire sauce)
# 15  0.119017                        (diced tomatoes)
# 8   0.113195                         (chicken broth)
# 7   0.111902                           (celery ribs)
# 3   0.109961                          (black pepper)
# 26  0.109314                             (hot sauce)
# 16  0.104787                         (dried oregano)
# 38  0.104787                       (red bell pepper)
# 21  0.100906                         (garlic powder)
# 10  0.093790                        (chopped celery)
# 35  0.085382                                  (okra)
# 44  0.076973                       (unsalted butter)
# 43  0.074386                              (tomatoes)
# 12  0.071151                         (chopped onion)
# 30  0.069211                       (long-grain rice)
# 19  0.069211                                 (flour)
# 25  0.068564                     (ground red pepper)
# 1   0.068564                              (bay leaf)
# 27  0.067917                           (kosher salt)
# 13  0.066624                           (cooked rice)
# 54  0.065977            (dried thyme, dried oregano)
# 41  0.065330                        (smoked sausage)
# 24  0.064683                          (green pepper)
# 53  0.064036        (green bell pepper, celery ribs)
# 52  0.064036             (green bell pepper, celery)
# 34  0.063389                         (minced garlic)
# 32  0.061449                         (medium shrimp)
# 47  0.060802  (green bell pepper, andouille sausage)
# 42  0.058862                          (tomato paste)
# 11  0.056921             (chopped green bell pepper)
# 50  0.056921     (cayenne pepper, green bell pepper)
# 36  0.056921                          (onion powder)
# 49  0.056274           (cayenne pepper, dried thyme)
# 18  0.056274                                  (eggs)
# 46  0.055627                          (yellow onion)
# 48  0.055627         (green bell pepper, bay leaves)
# 51  0.054981               (cayenne pepper, paprika)
# 39  0.054334                             (scallions)
# 33  0.054334                                  (milk)
# 28  0.053687                            (large eggs)
# 29  0.052393                          (large shrimp)
# 31  0.051746                             (mayonaise)
# 9   0.051746                         (chicken stock)
# 55  0.051746                (garlic powder, paprika)
#             antecedents          consequents   support  confidence
# 0         (dried thyme)      (dried oregano)  0.065977    0.421488
# 1       (dried oregano)        (dried thyme)  0.065977    0.629630
# 2   (green bell pepper)        (celery ribs)  0.064036    0.294643
# 3         (celery ribs)  (green bell pepper)  0.064036    0.572254
# 4   (green bell pepper)             (celery)  0.064036    0.294643
# 5              (celery)  (green bell pepper)  0.064036    0.402439
# 6   (green bell pepper)  (andouille sausage)  0.060802    0.279762
# 7   (andouille sausage)  (green bell pepper)  0.060802    0.419643
# 8      (cayenne pepper)  (green bell pepper)  0.056921    0.296296
# 9   (green bell pepper)     (cayenne pepper)  0.056921    0.261905
# 10     (cayenne pepper)        (dried thyme)  0.056274    0.292929
# 11        (dried thyme)     (cayenne pepper)  0.056274    0.359504
# 12  (green bell pepper)         (bay leaves)  0.055627    0.255952
# 13         (bay leaves)  (green bell pepper)  0.055627    0.390909
# 14     (cayenne pepper)            (paprika)  0.054981    0.286195
# 15            (paprika)     (cayenne pepper)  0.054981    0.442708
# 16      (garlic powder)            (paprika)  0.051746    0.512821
# 17            (paprika)      (garlic powder)  0.051746    0.416667
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:585: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   and cb.iterable(edge_color) \
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:595: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   for c in edge_color]):
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:676: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cb.iterable(node_size):  # many node sizes
# cajun_creole

# %%
# brazilian
create_rules(filtered['brazilian'])
print('brazilian')
# Out:
#      support                    itemsets
# 7   0.190578                      (lime)
# 2   0.149893                   (cachaca)
# 12  0.134904                  (tomatoes)
# 4   0.124197              (coconut milk)
# 11  0.122056  (sweetened condensed milk)
# 5   0.111349                      (eggs)
# 9   0.094218                      (milk)
# 13  0.092077             (lime, cachaca)
# 1   0.077088               (black beans)
# 0   0.062099                (bay leaves)
# 10  0.062099           (red bell pepper)
# 3   0.055675                   (carrots)
# 6   0.055675                       (ice)
# 8   0.053533                (lime juice)
#   antecedents consequents   support  confidence
# 0      (lime)   (cachaca)  0.092077    0.483146
# 1   (cachaca)      (lime)  0.092077    0.614286
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-259-fabcc505c402> in <module>
#       1 # brazilian
# ----> 2 create_rules(filtered['brazilian'])
#       3 print('brazilian')
#
# <ipython-input-203-6b0b03a3f5b0> in create_rules(cuisine_data)
#      14
#      15     # draw graph
# ---> 16     draw_graph(rules, 10)
#
# <ipython-input-202-98811bab647f> in draw_graph(rules, num_rules)
#      10         graph.add_node("R"+str(i))
#      11
# ---> 12         for a in rules.iloc[i]['antecedents']:
#      13             graph.add_node(a)
#      14             graph.add_edge(a, "R"+str(i), color=colors[i] , weight = 2)
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1498
#    1499             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1500             return self._getitem_axis(maybe_callable, axis=axis)
#    1501
#    1502     def _is_scalar_access(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    2228
#    2229             # validate the location
# -> 2230             self._validate_integer(key, axis)
#    2231
#    2232             return self._get_loc(key, axis=axis)
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_integer(self, key, axis)
#    2137         len_axis = len(self.obj._get_axis(axis))
#    2138         if key >= len_axis or key < -len_axis:
# -> 2139             raise IndexError("single positional indexer is out-of-bounds")
#    2140
#    2141     def _getitem_tuple(self, tup):
#
# IndexError: single positional indexer is out-of-bounds

# %%
# french
create_rules(filtered['french'])
print('french')
# Out:
#      support                       itemsets
# 18  0.223734              (unsalted butter)
# 14  0.156841                   (large eggs)
# 17  0.121315                     (shallots)
# 7   0.096750       (extra-virgin olive oil)
# 5   0.092593               (dry white wine)
# 8   0.090325            (fresh lemon juice)
# 13  0.083900              (large egg yolks)
# 2   0.083522                      (carrots)
# 19  0.082766              (vanilla extract)
# 10  0.079365                  (heavy cream)
# 16  0.071051                         (milk)
# 21  0.070295  (unsalted butter, large eggs)
# 6   0.069917                         (eggs)
# 1   0.065004                 (black pepper)
# 20  0.064626               (whipping cream)
# 4   0.064248                (dijon mustard)
# 3   0.062736                (cooking spray)
# 9   0.062736                (fresh parsley)
# 11  0.057823                  (kosher salt)
# 0   0.056311                     (bay leaf)
# 15  0.051776                        (leeks)
# 12  0.051398             (large egg whites)
#          antecedents        consequents   support  confidence
# 0  (unsalted butter)       (large eggs)  0.070295    0.314189
# 1       (large eggs)  (unsalted butter)  0.070295    0.448193
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-260-9cdbb849d5e3> in <module>
#       1 # french
# ----> 2 create_rules(filtered['french'])
#       3 print('french')
#
# <ipython-input-203-6b0b03a3f5b0> in create_rules(cuisine_data)
#      14
#      15     # draw graph
# ---> 16     draw_graph(rules, 10)
#
# <ipython-input-202-98811bab647f> in draw_graph(rules, num_rules)
#      10         graph.add_node("R"+str(i))
#      11
# ---> 12         for a in rules.iloc[i]['antecedents']:
#      13             graph.add_node(a)
#      14             graph.add_edge(a, "R"+str(i), color=colors[i] , weight = 2)
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1498
#    1499             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1500             return self._getitem_axis(maybe_callable, axis=axis)
#    1501
#    1502     def _is_scalar_access(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    2228
#    2229             # validate the location
# -> 2230             self._validate_integer(key, axis)
#    2231
#    2232             return self._get_loc(key, axis=axis)
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_integer(self, key, axis)
#    2137         len_axis = len(self.obj._get_axis(axis))
#    2138         if key >= len_axis or key < -len_axis:
# -> 2139             raise IndexError("single positional indexer is out-of-bounds")
#    2140
#    2141     def _getitem_tuple(self, tup):
#
# IndexError: single positional indexer is out-of-bounds

# %%
# japanese
create_rules(filtered['japanese'])
print('japanese')
# Out:
#      support                   itemsets
# 18  0.394238                (soy sauce)
# 10  0.282502                    (mirin)
# 14  0.203092                     (sake)
# 13  0.183415             (rice vinegar)
# 26  0.170063         (soy sauce, mirin)
# 15  0.160928                (scallions)
# 5   0.133521                   (ginger)
# 16  0.130710               (sesame oil)
# 28  0.129304          (soy sauce, sake)
# 0   0.129304                  (carrots)
# 6   0.122980             (green onions)
# 24  0.118763              (sake, mirin)
# 12  0.102600                      (oil)
# 3   0.101195                     (eggs)
# 17  0.087843             (sesame seeds)
# 4   0.087140             (fresh ginger)
# 2   0.086437                    (dashi)
# 27  0.085734  (soy sauce, rice vinegar)
# 22  0.080112        (soy sauce, ginger)
# 29  0.079410     (soy sauce, scallions)
# 31  0.078707   (soy sauce, sake, mirin)
# 30  0.077301    (soy sauce, sesame oil)
# 23  0.065355  (soy sauce, green onions)
# 1   0.063247              (corn starch)
# 25  0.059733         (scallions, mirin)
# 11  0.059030                     (nori)
# 8   0.056219              (kosher salt)
# 19  0.055517       (carrots, soy sauce)
# 9   0.052706               (large eggs)
# 20  0.052706            (ginger, mirin)
# 7   0.051300                    (honey)
# 21  0.051300             (sake, ginger)
#            antecedents         consequents   support  confidence
# 0          (soy sauce)             (mirin)  0.170063    0.431373
# 1              (mirin)         (soy sauce)  0.170063    0.601990
# 2          (soy sauce)              (sake)  0.129304    0.327986
# 3               (sake)         (soy sauce)  0.129304    0.636678
# 4               (sake)             (mirin)  0.118763    0.584775
# 5              (mirin)              (sake)  0.118763    0.420398
# 6          (soy sauce)      (rice vinegar)  0.085734    0.217469
# 7       (rice vinegar)         (soy sauce)  0.085734    0.467433
# 8          (soy sauce)            (ginger)  0.080112    0.203209
# 9             (ginger)         (soy sauce)  0.080112    0.600000
# 10         (soy sauce)         (scallions)  0.079410    0.201426
# 11         (scallions)         (soy sauce)  0.079410    0.493450
# 12   (soy sauce, sake)             (mirin)  0.078707    0.608696
# 13  (soy sauce, mirin)              (sake)  0.078707    0.462810
# 14       (sake, mirin)         (soy sauce)  0.078707    0.662722
# 15              (sake)  (soy sauce, mirin)  0.078707    0.387543
# 16             (mirin)   (soy sauce, sake)  0.078707    0.278607
# 17        (sesame oil)         (soy sauce)  0.077301    0.591398
# 18      (green onions)         (soy sauce)  0.065355    0.531429
# 19         (scallions)             (mirin)  0.059733    0.371179
# 20             (mirin)         (scallions)  0.059733    0.211443
# 21           (carrots)         (soy sauce)  0.055517    0.429348
# 22            (ginger)             (mirin)  0.052706    0.394737
# 23              (sake)            (ginger)  0.051300    0.252595
# 24            (ginger)              (sake)  0.051300    0.384211
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:585: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   and cb.iterable(edge_color) \
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:595: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   for c in edge_color]):
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:676: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cb.iterable(node_size):  # many node sizes
# japanese

# %%
# irish
create_rules(filtered['irish'])
print('irish')
# Out:
#      support                      itemsets
# 16  0.179910                    (potatoes)
# 2   0.172414                 (baking soda)
# 1   0.167916               (baking powder)
# 15  0.166417                        (milk)
# 7   0.157421                     (carrots)
# 9   0.134933                        (eggs)
# 18  0.130435             (unsalted butter)
# 13  0.115442                  (large eggs)
# 5   0.112444                  (buttermilk)
# 23  0.098951     (buttermilk, baking soda)
# 20  0.094453  (baking powder, baking soda)
# 6   0.080960                     (cabbage)
# 8   0.071964               (cooking spray)
# 3   0.065967                (black pepper)
# 24  0.062969           (carrots, potatoes)
# 10  0.062969                       (flour)
# 17  0.059970                     (raisins)
# 11  0.059970               (fresh parsley)
# 12  0.058471                 (heavy cream)
# 14  0.056972                       (leeks)
# 19  0.056972           (whole wheat flour)
# 4   0.056972                 (brown sugar)
# 0   0.053973                       (bacon)
# 22  0.052474   (baking powder, large eggs)
# 21  0.052474   (baking powder, buttermilk)
# 25  0.050975              (potatoes, milk)
#         antecedents      consequents   support  confidence
# 0      (buttermilk)    (baking soda)  0.098951    0.880000
# 1     (baking soda)     (buttermilk)  0.098951    0.573913
# 2   (baking powder)    (baking soda)  0.094453    0.562500
# 3     (baking soda)  (baking powder)  0.094453    0.547826
# 4         (carrots)       (potatoes)  0.062969    0.400000
# 5        (potatoes)        (carrots)  0.062969    0.350000
# 6   (baking powder)     (large eggs)  0.052474    0.312500
# 7      (large eggs)  (baking powder)  0.052474    0.454545
# 8   (baking powder)     (buttermilk)  0.052474    0.312500
# 9      (buttermilk)  (baking powder)  0.052474    0.466667
# 10       (potatoes)           (milk)  0.050975    0.283333
# 11           (milk)       (potatoes)  0.050975    0.306306
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:585: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   and cb.iterable(edge_color) \
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:595: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   for c in edge_color]):
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:676: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cb.iterable(node_size):  # many node sizes
# irish

# %%
# korean
create_rules(filtered['korean'])
print('korean')
# Out:
#      support                                       itemsets
# 26  0.514458                                    (soy sauce)
# 23  0.485542                                   (sesame oil)
# 11  0.353012                                 (green onions)
# 70  0.339759                        (soy sauce, sesame oil)
# 24  0.268675                                 (sesame seeds)
# 22  0.236145                                    (scallions)
# 52  0.209639                     (sesame oil, green onions)
# 54  0.206024                      (soy sauce, green onions)
# 5   0.204819                                      (carrots)
# 69  0.181928                     (sesame seeds, sesame oil)
# 72  0.178313                      (soy sauce, sesame seeds)
# 10  0.173494                                       (ginger)
# 0   0.163855                               (Gochujang base)
# 20  0.153012                                 (rice vinegar)
# 83  0.153012          (soy sauce, sesame oil, green onions)
# 3   0.139759                                  (brown sugar)
# 89  0.137349          (soy sauce, sesame oil, sesame seeds)
# 29  0.136145                         (toasted sesame seeds)
# 13  0.127711                                       (kimchi)
# 7   0.126506                                         (eggs)
# 53  0.125301                   (sesame seeds, green onions)
# 9   0.122892                                 (fresh ginger)
# 68  0.120482                         (soy sauce, scallions)
# 43  0.119277                           (soy sauce, carrots)
# 16  0.116867                                (minced garlic)
# 41  0.112048                          (carrots, sesame oil)
# 51  0.104819                            (soy sauce, ginger)
# 66  0.102410                        (scallions, sesame oil)
# 82  0.098795       (sesame seeds, sesame oil, green onions)
# 2   0.097590                                 (black pepper)
# ..       ...                                            ...
# 39  0.063855                        (carrots, green onions)
# 42  0.063855                        (sesame seeds, carrots)
# 47  0.063855                      (soy sauce, fresh ginger)
# 18  0.062651                                 (napa cabbage)
# 6   0.061446                                     (cucumber)
# 30  0.061446                                     (zucchini)
# 57  0.060241                           (sesame oil, kimchi)
# 31  0.060241                 (green onions, Gochujang base)
# 75  0.059036        (soy sauce, sesame oil, Gochujang base)
# 85  0.057831                 (soy sauce, honey, sesame oil)
# 8   0.057831                                   (fish sauce)
# 25  0.056627                                     (shiitake)
# 73  0.056627                (soy sauce, toasted sesame oil)
# 4   0.055422                                   (canola oil)
# 27  0.055422                                (spring onions)
# 46  0.055422                     (sesame oil, fresh ginger)
# 76  0.054217          (soy sauce, black pepper, sesame oil)
# 15  0.054217                         (low sodium soy sauce)
# 65  0.054217                         (soy sauce, rice wine)
# 64  0.054217                        (sesame oil, rice wine)
# 80  0.053012                  (soy sauce, sesame oil, eggs)
# 86  0.053012         (soy sauce, sesame oil, minced garlic)
# 40  0.053012                           (carrots, scallions)
# 90  0.053012  (soy sauce, sesame oil, toasted sesame seeds)
# 50  0.051807                         (sesame seeds, ginger)
# 67  0.051807                      (sesame seeds, scallions)
# 87  0.051807          (soy sauce, sesame oil, rice vinegar)
# 1   0.051807                                         (beef)
# 77  0.050602         (soy sauce, green onions, brown sugar)
# 61  0.050602                 (soy sauce, red pepper flakes)
#
# [92 rows x 2 columns]
#                             antecedents                 consequents   support  \
# 0                           (soy sauce)                (sesame oil)  0.339759
# 1                          (sesame oil)                 (soy sauce)  0.339759
# 2                          (sesame oil)              (green onions)  0.209639
# 3                        (green onions)                (sesame oil)  0.209639
# 4                           (soy sauce)              (green onions)  0.206024
# 5                        (green onions)                 (soy sauce)  0.206024
# 6                        (sesame seeds)                (sesame oil)  0.181928
# 7                          (sesame oil)              (sesame seeds)  0.181928
# 8                           (soy sauce)              (sesame seeds)  0.178313
# 9                        (sesame seeds)                 (soy sauce)  0.178313
# 10              (soy sauce, sesame oil)              (green onions)  0.153012
# 11            (soy sauce, green onions)                (sesame oil)  0.153012
# 12           (sesame oil, green onions)                 (soy sauce)  0.153012
# 13                          (soy sauce)  (sesame oil, green onions)  0.153012
# 14                         (sesame oil)   (soy sauce, green onions)  0.153012
# 15                       (green onions)     (soy sauce, sesame oil)  0.153012
# 16              (soy sauce, sesame oil)              (sesame seeds)  0.137349
# 17            (soy sauce, sesame seeds)                (sesame oil)  0.137349
# 18           (sesame seeds, sesame oil)                 (soy sauce)  0.137349
# 19                          (soy sauce)  (sesame seeds, sesame oil)  0.137349
# 20                         (sesame oil)   (soy sauce, sesame seeds)  0.137349
# 21                       (sesame seeds)     (soy sauce, sesame oil)  0.137349
# 22                       (sesame seeds)              (green onions)  0.125301
# 23                       (green onions)              (sesame seeds)  0.125301
# 24                          (soy sauce)                 (scallions)  0.120482
# 25                          (scallions)                 (soy sauce)  0.120482
# 26                          (soy sauce)                   (carrots)  0.119277
# 27                            (carrots)                 (soy sauce)  0.119277
# 28                            (carrots)                (sesame oil)  0.112048
# 29                         (sesame oil)                   (carrots)  0.112048
# ..                                  ...                         ...       ...
# 102                 (honey, sesame oil)                 (soy sauce)  0.057831
# 103                             (honey)     (soy sauce, sesame oil)  0.057831
# 104                (toasted sesame oil)                 (soy sauce)  0.056627
# 105                      (fresh ginger)                (sesame oil)  0.055422
# 106           (soy sauce, black pepper)                (sesame oil)  0.054217
# 107          (black pepper, sesame oil)                 (soy sauce)  0.054217
# 108                      (black pepper)     (soy sauce, sesame oil)  0.054217
# 109                         (rice wine)                 (soy sauce)  0.054217
# 110                         (rice wine)                (sesame oil)  0.054217
# 111                   (soy sauce, eggs)                (sesame oil)  0.053012
# 112                  (sesame oil, eggs)                 (soy sauce)  0.053012
# 113                              (eggs)     (soy sauce, sesame oil)  0.053012
# 114          (soy sauce, minced garlic)                (sesame oil)  0.053012
# 115         (sesame oil, minced garlic)                 (soy sauce)  0.053012
# 116                     (minced garlic)     (soy sauce, sesame oil)  0.053012
# 117                           (carrots)                 (scallions)  0.053012
# 118                         (scallions)                   (carrots)  0.053012
# 119   (soy sauce, toasted sesame seeds)                (sesame oil)  0.053012
# 120  (sesame oil, toasted sesame seeds)                 (soy sauce)  0.053012
# 121              (toasted sesame seeds)     (soy sauce, sesame oil)  0.053012
# 122                            (ginger)              (sesame seeds)  0.051807
# 123                         (scallions)              (sesame seeds)  0.051807
# 124           (soy sauce, rice vinegar)                (sesame oil)  0.051807
# 125          (sesame oil, rice vinegar)                 (soy sauce)  0.051807
# 126                      (rice vinegar)     (soy sauce, sesame oil)  0.051807
# 127           (soy sauce, green onions)               (brown sugar)  0.050602
# 128            (soy sauce, brown sugar)              (green onions)  0.050602
# 129         (green onions, brown sugar)                 (soy sauce)  0.050602
# 130                       (brown sugar)   (soy sauce, green onions)  0.050602
# 131                 (red pepper flakes)                 (soy sauce)  0.050602
#
#      confidence
# 0      0.660422
# 1      0.699752
# 2      0.431762
# 3      0.593857
# 4      0.400468
# 5      0.583618
# 6      0.677130
# 7      0.374690
# 8      0.346604
# 9      0.663677
# 10     0.450355
# 11     0.742690
# 12     0.729885
# 13     0.297424
# 14     0.315136
# 15     0.433447
# 16     0.404255
# 17     0.770270
# 18     0.754967
# 19     0.266979
# 20     0.282878
# 21     0.511211
# 22     0.466368
# 23     0.354949
# 24     0.234192
# 25     0.510204
# 26     0.231850
# 27     0.582353
# 28     0.547059
# 29     0.230769
# ..          ...
# 102    0.827586
# 103    0.600000
# 104    0.610390
# 105    0.450980
# 106    0.818182
# 107    0.803571
# 108    0.555556
# 109    0.803571
# 110    0.803571
# 111    0.721311
# 112    0.721311
# 113    0.419048
# 114    0.698413
# 115    0.758621
# 116    0.453608
# 117    0.258824
# 118    0.224490
# 119    0.647059
# 120    0.698413
# 121    0.389381
# 122    0.298611
# 123    0.219388
# 124    0.605634
# 125    0.682540
# 126    0.338583
# 127    0.245614
# 128    0.531646
# 129    0.792453
# 130    0.362069
# 131    0.792453
#
# [132 rows x 4 columns]
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:585: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   and cb.iterable(edge_color) \
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:595: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   for c in edge_color]):
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:676: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cb.iterable(node_size):  # many node sizes
# korean

# %%
# moroccan
create_rules(filtered['moroccan'])
print('moroccan')
# Out:
#      support                                           itemsets
# 24  0.423873                                     (ground cumin)
# 22  0.271620                                  (ground cinnamon)
# 25  0.213155                                    (ground ginger)
# 1   0.188794                                          (carrots)
# 31  0.182704                                          (paprika)
# 8   0.172960                                         (couscous)
# 23  0.168088                                 (ground coriander)
# 58  0.165652                    (ground cumin, ground cinnamon)
# 13  0.155907                           (extra-virgin olive oil)
# 4   0.154689                                        (chickpeas)
# 16  0.153471                                (fresh lemon juice)
# 5   0.148599                           (chopped cilantro fresh)
# 6   0.146163                                         (cinnamon)
# 61  0.144945                   (ground cumin, ground coriander)
# 29  0.132765                                            (lemon)
# 42  0.132765                                          (tumeric)
# 27  0.121803                                            (honey)
# 62  0.118149                      (ground cumin, ground ginger)
# 66  0.113276                            (ground cumin, paprika)
# 28  0.112058                                      (kosher salt)
# 0   0.112058                                     (black pepper)
# 18  0.105968                                    (fresh parsley)
# 2   0.103532                                   (cayenne pepper)
# 59  0.096224                   (ground cinnamon, ground ginger)
# 30  0.090134                                      (lemon juice)
# 41  0.090134                                         (tomatoes)
# 46  0.090134                            (carrots, ground cumin)
# 26  0.087698                                  (ground turmeric)
# 12  0.087698                                    (dried apricot)
# 51  0.085262             (ground cumin, chopped cilantro fresh)
# ..       ...                                                ...
# 32  0.070646                                  (preserved lemon)
# 53  0.069428                        (couscous, ground cinnamon)
# 37  0.068210                                          (saffron)
# 40  0.068210                                     (tomato paste)
# 45  0.068210                         (carrots, ground cinnamon)
# 48  0.065773                     (cayenne pepper, ground cumin)
# 67  0.065773  (ground cumin, ground cinnamon, ground coriander)
# 3   0.064555                                    (chicken stock)
# 11  0.064555                                   (diced tomatoes)
# 55  0.063337             (extra-virgin olive oil, ground cumin)
# 19  0.063337                                           (ginger)
# 20  0.059683                                   (golden raisins)
# 34  0.058465                                          (raisins)
# 68  0.058465     (ground cumin, ground cinnamon, ground ginger)
# 15  0.058465                                   (fresh cilantro)
# 44  0.058465                                     (yellow onion)
# 36  0.056029                                  (red bell pepper)
# 65  0.056029                              (ground cumin, lemon)
# 64  0.056029                        (ground cumin, kosher salt)
# 60  0.056029                         (ground cinnamon, paprika)
# 21  0.054811                                     (green olives)
# 49  0.053593                       (chickpeas, ground cinnamon)
# 63  0.053593                    (ground cumin, ground turmeric)
# 35  0.052375                                    (ras el hanout)
# 17  0.052375                                       (fresh mint)
# 39  0.052375                                    (sweet paprika)
# 43  0.052375                                  (unsalted butter)
# 47  0.052375                           (carrots, ground ginger)
# 52  0.052375                                (tumeric, cinnamon)
# 10  0.051157                                       (cumin seed)
#
# [69 rows x 2 columns]
#                             antecedents                       consequents  \
# 0                        (ground cumin)                 (ground cinnamon)
# 1                     (ground cinnamon)                    (ground cumin)
# 2                        (ground cumin)                (ground coriander)
# 3                    (ground coriander)                    (ground cumin)
# 4                        (ground cumin)                   (ground ginger)
# 5                       (ground ginger)                    (ground cumin)
# 6                        (ground cumin)                         (paprika)
# 7                             (paprika)                    (ground cumin)
# 8                     (ground cinnamon)                   (ground ginger)
# 9                       (ground ginger)                 (ground cinnamon)
# 10                            (carrots)                    (ground cumin)
# 11                       (ground cumin)                         (carrots)
# 12                       (ground cumin)          (chopped cilantro fresh)
# 13             (chopped cilantro fresh)                    (ground cumin)
# 14                           (couscous)                    (ground cumin)
# 15                  (fresh lemon juice)                    (ground cumin)
# 16                    (ground cinnamon)                (ground coriander)
# 17                   (ground coriander)                 (ground cinnamon)
# 18                          (chickpeas)                    (ground cumin)
# 19                           (couscous)                 (ground cinnamon)
# 20                    (ground cinnamon)                        (couscous)
# 21                            (carrots)                 (ground cinnamon)
# 22                    (ground cinnamon)                         (carrots)
# 23                     (cayenne pepper)                    (ground cumin)
# 24      (ground cumin, ground cinnamon)                (ground coriander)
# 25     (ground cumin, ground coriander)                 (ground cinnamon)
# 26  (ground cinnamon, ground coriander)                    (ground cumin)
# 27                    (ground cinnamon)  (ground cumin, ground coriander)
# 28                   (ground coriander)   (ground cumin, ground cinnamon)
# 29             (extra-virgin olive oil)                    (ground cumin)
# 30      (ground cumin, ground cinnamon)                   (ground ginger)
# 31        (ground cumin, ground ginger)                 (ground cinnamon)
# 32     (ground cinnamon, ground ginger)                    (ground cumin)
# 33                    (ground cinnamon)     (ground cumin, ground ginger)
# 34                      (ground ginger)   (ground cumin, ground cinnamon)
# 35                              (lemon)                    (ground cumin)
# 36                        (kosher salt)                    (ground cumin)
# 37                    (ground cinnamon)                         (paprika)
# 38                            (paprika)                 (ground cinnamon)
# 39                          (chickpeas)                 (ground cinnamon)
# 40                    (ground turmeric)                    (ground cumin)
# 41                            (carrots)                   (ground ginger)
# 42                      (ground ginger)                         (carrots)
# 43                            (tumeric)                        (cinnamon)
# 44                           (cinnamon)                         (tumeric)
#
#      support  confidence
# 0   0.165652    0.390805
# 1   0.165652    0.609865
# 2   0.144945    0.341954
# 3   0.144945    0.862319
# 4   0.118149    0.278736
# 5   0.118149    0.554286
# 6   0.113276    0.267241
# 7   0.113276    0.620000
# 8   0.096224    0.354260
# 9   0.096224    0.451429
# 10  0.090134    0.477419
# 11  0.090134    0.212644
# 12  0.085262    0.201149
# 13  0.085262    0.573770
# 14  0.082826    0.478873
# 15  0.076736    0.500000
# 16  0.075518    0.278027
# 17  0.075518    0.449275
# 18  0.074300    0.480315
# 19  0.069428    0.401408
# 20  0.069428    0.255605
# 21  0.068210    0.361290
# 22  0.068210    0.251121
# 23  0.065773    0.635294
# 24  0.065773    0.397059
# 25  0.065773    0.453782
# 26  0.065773    0.870968
# 27  0.065773    0.242152
# 28  0.065773    0.391304
# 29  0.063337    0.406250
# 30  0.058465    0.352941
# 31  0.058465    0.494845
# 32  0.058465    0.607595
# 33  0.058465    0.215247
# 34  0.058465    0.274286
# 35  0.056029    0.422018
# 36  0.056029    0.500000
# 37  0.056029    0.206278
# 38  0.056029    0.306667
# 39  0.053593    0.346457
# 40  0.053593    0.611111
# 41  0.052375    0.277419
# 42  0.052375    0.245714
# 43  0.052375    0.394495
# 44  0.052375    0.358333
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:585: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   and cb.iterable(edge_color) \
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:595: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   for c in edge_color]):
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:676: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cb.iterable(node_size):  # many node sizes
# moroccan

# %%
# russian
create_rules(filtered['russian'])
print('russian')
# Out:
#      support                       itemsets
# 19  0.239264                   (sour cream)
# 8   0.229039                         (eggs)
# 20  0.190184              (unsalted butter)
# 11  0.173824                   (large eggs)
# 6   0.157464                      (carrots)
# 15  0.134969                         (milk)
# 16  0.134969                     (potatoes)
# 9   0.124744                        (flour)
# 10  0.110429                   (fresh dill)
# 3   0.108384                        (beets)
# 29  0.098160  (unsalted butter, large eggs)
# 25  0.085890                  (flour, eggs)
# 26  0.079755                   (eggs, milk)
# 5   0.075665                      (cabbage)
# 23  0.075665            (carrots, potatoes)
# 0   0.071575             (active dry yeast)
# 1   0.071575                (baking powder)
# 4   0.071575                 (black pepper)
# 7   0.065440                         (dill)
# 14  0.063395                    (mayonaise)
# 13  0.063395                  (lemon juice)
# 12  0.063395                        (lemon)
# 22  0.061350               (carrots, beets)
# 21  0.059305              (vanilla extract)
# 18  0.057260                      (raisins)
# 24  0.057260          (carrots, sour cream)
# 17  0.053170               (powdered sugar)
# 27  0.051125             (sour cream, eggs)
# 28  0.051125                  (flour, milk)
# 2   0.051125                   (bay leaves)
# 30  0.051125         (sour cream, potatoes)
#           antecedents        consequents   support  confidence
# 0   (unsalted butter)       (large eggs)  0.098160    0.516129
# 1        (large eggs)  (unsalted butter)  0.098160    0.564706
# 2             (flour)             (eggs)  0.085890    0.688525
# 3              (eggs)            (flour)  0.085890    0.375000
# 4              (eggs)             (milk)  0.079755    0.348214
# 5              (milk)             (eggs)  0.079755    0.590909
# 6           (carrots)         (potatoes)  0.075665    0.480519
# 7          (potatoes)          (carrots)  0.075665    0.560606
# 8           (carrots)            (beets)  0.061350    0.389610
# 9             (beets)          (carrots)  0.061350    0.566038
# 10          (carrots)       (sour cream)  0.057260    0.363636
# 11       (sour cream)          (carrots)  0.057260    0.239316
# 12       (sour cream)             (eggs)  0.051125    0.213675
# 13             (eggs)       (sour cream)  0.051125    0.223214
# 14            (flour)             (milk)  0.051125    0.409836
# 15             (milk)            (flour)  0.051125    0.378788
# 16       (sour cream)         (potatoes)  0.051125    0.213675
# 17         (potatoes)       (sour cream)  0.051125    0.378788
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:585: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   and cb.iterable(edge_color) \
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:595: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   for c in edge_color]):
# C:\Users\Remi\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:676: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cb.iterable(node_size):  # many node sizes
# russian
